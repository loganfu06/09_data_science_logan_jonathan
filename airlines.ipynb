# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
df_data = pd.read_excel('airlines.xlsx')
df_data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df_data = df_data.dropna()

# %%
df_data.isnull().values.all()
# Out:
# False

# %%
df_data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df_data['Date_of_Journey'] = pd.to_datetime(df_data['Date_of_Journey'])
df_data
# Out:
# /tmp/ipykernel_44301/3497762225.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_data['Date_of_Journey'] = pd.to_datetime(df_data['Date_of_Journey'])
# /tmp/ipykernel_44301/3497762225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Date_of_Journey'] = pd.to_datetime(df_data['Date_of_Journey'])
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# ...

# %%
df_data['Dep_Time'] = pd.to_datetime(df_data['Dep_Time']).dt.time
df_data
# Out:
# /tmp/ipykernel_44301/3458326004.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_data['Dep_Time'] = pd.to_datetime(df_data['Dep_Time']).dt.time
# /tmp/ipykernel_44301/3458326004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Dep_Time'] = pd.to_datetime(df_data['Dep_Time']).dt.time
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# ...

# %%
df_data['Arrival_Time'] = pd.to_datetime(df_data['Arrival_Time']).dt.time
df_data
# Out:
# /tmp/ipykernel_44301/4009787825.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_data['Arrival_Time'] = pd.to_datetime(df_data['Arrival_Time']).dt.time
# /tmp/ipykernel_44301/4009787825.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Arrival_Time'] = pd.to_datetime(df_data['Arrival_Time']).dt.time
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# ...

# %%
df_data['Duration'] = pd.to_timedelta(df_data['Duration'])
df_data
# Out:
# /tmp/ipykernel_44301/1521431700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Duration'] = pd.to_timedelta(df_data['Duration'])
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# ...

# %%
df_data['Journey_day'] = df_data['Date_of_Journey'].apply(lambda x: x.day)
df_data['Journey_month'] = df_data['Date_of_Journey'].apply(lambda x: x.month)
df_data['Journey_year'] = df_data['Date_of_Journey'].apply(lambda x: x.year)
df_data
# Out:
# /tmp/ipykernel_44301/2030564962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Journey_day'] = df_data['Date_of_Journey'].apply(lambda x: x.day)
# /tmp/ipykernel_44301/2030564962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Journey_month'] = df_data['Date_of_Journey'].apply(lambda x: x.month)
# /tmp/ipykernel_44301/2030564962.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_data['Dep_Time_hour'] = df_data['Dep_Time'].apply(lambda x: x.hour)
df_data['Dep_Time_minute'] = df_data['Dep_Time'].apply(lambda x: x.minute)
df_data['Arrival_Time_hour'] = df_data['Arrival_Time'].apply(lambda x: x.hour)
df_data['Arrival_Time_minute'] = df_data['Arrival_Time'].apply(lambda x: x.minute)
df_data
# Out:
# /tmp/ipykernel_44301/3274071045.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Dep_Time_hour'] = df_data['Dep_Time'].apply(lambda x: x.hour)
# /tmp/ipykernel_44301/3274071045.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Dep_Time_minute'] = df_data['Dep_Time'].apply(lambda x: x.minute)
# /tmp/ipykernel_44301/3274071045.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
def get_description(time):
    if (time >= datetime.strptime('4:00:00','%H:%M:%S').time()) and (time < datetime.strptime('8:00:00','%H:%M:%S').time()):
        return 'Early Morning'
    elif (time >= datetime.strptime('8:00:00','%H:%M:%S').time()) and (time < datetime.strptime('12:00:00','%H:%M:%S').time()):
        return 'Morning'
    elif (time >= datetime.strptime('12:00:00','%H:%M:%S').time()) and (time < datetime.strptime('16:00:00','%H:%M:%S').time()):
        return 'Noon'
    elif (time >= datetime.strptime('16:00:00','%H:%M:%S').time()) and (time < datetime.strptime('20:00:00','%H:%M:%S').time()):
        return 'Evening'
    elif (time >= datetime.strptime('20:00:00','%H:%M:%S').time()) and (time <= datetime.strptime('23:59:00','%H:%M:%S').time()):
        return 'Night'
    elif (time >= datetime.strptime('00:00:00','%H:%M:%S').time()) and (time < datetime.strptime('4:00:00','%H:%M:%S').time()):
        return 'Late Night'

df_data['dep_description'] = df_data['Dep_Time'].apply(get_description)
df_data
# Out:
# /tmp/ipykernel_44301/1494840141.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['dep_description'] = df_data['Dep_Time'].apply(get_description)
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# ...

# %%
df_groupby = df_data.groupby('dep_description').size()
fig, ax = plt.subplots(figsize=(8,6))
ax.bar(df_groupby.index, df_groupby)
plt.ylabel('Number of flights')
plt.xlabel('Departure Time Description')
# Out:
# Text(0.5, 0, 'Departure Time Description')

# %%
df_data['Duration_hours'] = df_data['Duration'].apply(lambda x: x.seconds // 3600)
df_data['Duration_mins'] = df_data['Duration'].apply(lambda x: (x.seconds // 60) % 60)
df_data['Duration_total_mins'] = df_data['Duration'].apply(lambda x: x.seconds // 60)
df_data
# Out:
# /tmp/ipykernel_44301/1292792642.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Duration_hours'] = df_data['Duration'].apply(lambda x: x.seconds // 3600)
# /tmp/ipykernel_44301/1292792642.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Duration_mins'] = df_data['Duration'].apply(lambda x: (x.seconds // 60) % 60)
# /tmp/ipykernel_44301/1292792642.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
plt.scatter(df_data['Duration_total_mins'], df_data['Price'], alpha=0.1)
plt.xlabel('Total minutes of flight')
plt.ylabel('Price')

m,b = np.polyfit(df_data['Duration_total_mins'], df_data['Price'], 1)
plt.plot(df_data['Duration_total_mins'], m * df_data['Duration_total_mins'] + b, color='#FF0000')
# As the total minutes of the flight increase, the price of the flight increases

# %%
colors = df_data['Total_Stops'].map({'1 stop':'#FF0000', '2 stops':'#0000FF', '3 stops':'#00FF00', '4 stops':'#FFFF00', 'non-stop':'#000000'})
plt.scatter(df_data['Duration_total_mins'], df_data['Price'], c=colors, alpha=0.1)
plt.xlabel('Total minutes of flight')
plt.ylabel('Price')
# Most flights are for 1 stop. Non-stop flights are mainly concentrated under 200 minutes.
# Out:
# Text(0, 0.5, 'Price')

# %%
df_jet_airways = df_data.groupby('Airline').get_group("Jet Airways")
final_data = df_jet_airways.groupby('Route').size().sort_values(ascending=False).head(10)
plt.figure(figsize=(28,6))
plt.bar(final_data.index, final_data)
plt.xlabel('Route')
plt.ylabel('Number of flights')
plt.title('Most used routes by Jet Airways')

# CCU -> BOM -> BLR is the most used route by Jet Airways
# Out:
# Text(0.5, 1.0, 'Most used routes by Jet Airways')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from patsy import dmatrices

# %%
df_duration = df_data[df_data.Duration_total_mins.notnull()]
df_price = df_data[df_data.Duration_total_mins.notnull() & df_data.Price.notnull()]

# %%
df_price_duration = dmatrices("Price ~ Duration_total_mins - 1", df_price, return_type='dataframe')

# %%
df_price_duration
# Out:
# (         Price
#  0       3897.0
#  1       7662.0
#  2      13882.0
#  3       6218.0
#  4      13302.0
#  ...        ...
#  10678   4107.0
#  10679   4145.0
#  10680   7229.0
#  10681  12648.0
#  10682  11753.0
#
#  [10682 rows x 1 columns],
#         Duration_total_mins
#  0                    170.0
#  1                    445.0
#  2                   1140.0
#  3                    325.0
#  4                    285.0
#  ...                    ...
#  10678                150.0
#  10679                155.0
#  10680                180.0
#  10681                160.0
#  10682                500.0
#
#  [10682 rows x 1 columns])

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df_price_duration[1], df_price_duration[0], test_size=0.20, random_state=42)

# %%
model_price_duration = LinearRegression()
model_price_duration.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model_price_duration.score(x_train, y_train)
# The R2 score of roughly 0.201 indicates that there is relatively low correlation between duration and price.
# Out:
# 0.2005585827171643

# %%
plt.scatter(x_train.Duration_total_mins, y_train, label='wage age')
x_min, x_max = plt.xlim()
plt.plot([x_min, x_max],
         [model_price_duration.coef_[0][0]*x_min+ model_price_duration.intercept_[0],
          model_price_duration.coef_[0][0]*x_max+ model_price_duration.intercept_[0]],
          label="Linear regression", color="red")

# %%
df_price_factors = dmatrices("Price ~ Airline * Source * Destination * Total_Stops * dep_description * Journey_month * Journey_day", df_data, return_type='dataframe')

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df_price_factors[1], df_price_factors[0], test_size=0.20, random_state=42)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
